# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the datasets from the specified path with id column as index
train_path = "C:/Users/paulo/OneDrive/Documents/Binary-Classification-of-Insurance-Cross-Selling/train.csv"
test_path = "C:/Users/paulo/OneDrive/Documents/Binary-Classification-of-Insurance-Cross-Selling/test.csv"

train_df = pd.read_csv(train_path, index_col='id')
test_df = pd.read_csv(test_path, index_col='id')

# Use a 40% sample of the data
train_sample = train_df.sample(frac=0.4, random_state=42)
test_sample = test_df.sample(frac=0.4, random_state=42)

# Display the first few rows of the train sample
print("First few rows of the train sample:")
print(train_sample.head())

# Display the first few rows of the test sample
print("First few rows of the test sample:")
print(test_sample.head())

# Display basic information of the train sample
print("\nBasic Information of the Train Sample:")
print(train_sample.info())

# Display basic statistics of the train sample
print("\nBasic Statistics of the Train Sample:")
print(train_sample.describe())

# Check for missing values in the train sample
print("\nMissing Values in the Train Sample:")
print(train_sample.isnull().sum())

# Check for missing values in the test sample
print("\nMissing Values in the Test Sample:")
print(test_sample.isnull().sum())

# Visualize the distribution of numerical features
numerical_features = train_sample.select_dtypes(include=['int64', 'float64']).columns

for feature in numerical_features:
    plt.figure(figsize=(10, 6))
    sns.histplot(train_sample[feature], kde=True)
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()

# Visualize the distribution of categorical features
categorical_features = train_sample.select_dtypes(include=['object']).columns

for feature in categorical_features:
    plt.figure(figsize=(10, 6))
    sns.countplot(y=train_sample[feature], order=train_sample[feature].value_counts().index)
    plt.title(f'Distribution of {feature}')
    plt.xlabel('Count')
    plt.ylabel(feature)
    plt.show()
# Out:
# First few rows of the train sample:
#           Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# id
# 2899125   Female   41                1         28.0                   0
# 3854901   Female   40                1         28.0                   0
# 7377384     Male   31                1         18.0                   0
# 10901782  Female   24                1         37.0                   1
# 8099641     Male   33                1         28.0                   1
#
#          Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# id
# 2899125     1-2 Year            Yes         29590.0                 157.0
# 3854901     1-2 Year            Yes         42910.0                  13.0
# 7377384     < 1 Year            Yes         30375.0                 152.0
# 10901782    < 1 Year             No          2630.0                 152.0
# 8099641     1-2 Year             No         45224.0                 124.0
#
#           Vintage  Response
# id
# 2899125        46         0
# 3854901       245         0
# 7377384        31         0
# 10901782      217         0
# 8099641       286         0
# First few rows of the test sample:
#           Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# id
# 13992702    Male   41                1         47.0                   0
# 11616814  Female   27                1         50.0                   1
# 17046569    Male   23                1         47.0                   1
# 15312201    Male   27                1         24.0                   1
# 12478148  Female   46                1         46.0                   0
#
#          Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# id
# 13992702    1-2 Year            Yes         40255.0                  26.0
# 11616814    < 1 Year             No         29366.0                 152.0
# 17046569    < 1 Year             No         33807.0                 152.0
# 15312201    < 1 Year             No         35341.0                 152.0
# 12478148    1-2 Year            Yes          2630.0                  26.0
#
#           Vintage
# id
# 13992702      158
# 11616814      258
# 17046569       96
# 15312201      206
# 12478148      291
#
# Basic Information of the Train Sample:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4601919 entries, 2899125 to 5936552
# Data columns (total 11 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Gender                object
#  1   Age                   int64
#  2   Driving_License       int64
#  3   Region_Code           float64
#  4   Previously_Insured    int64
#  5   Vehicle_Age           object
#  6   Vehicle_Damage        object
#  7   Annual_Premium        float64
#  8   Policy_Sales_Channel  float64
#  9   Vintage               int64
#  10  Response              int64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 421.3+ MB
# None
#
# Basic Statistics of the Train Sample:
#                 Age  Driving_License   Region_Code  Previously_Insured  \
# count  4.601919e+06     4.601919e+06  4.601919e+06        4.601919e+06
# mean   3.837833e+01     9.979874e-01  2.641688e+01        4.632804e-01
# std    1.499162e+01     4.481728e-02  1.298827e+01        4.986499e-01
# min    2.000000e+01     0.000000e+00  0.000000e+00        0.000000e+00
# 25%    2.400000e+01     1.000000e+00  1.500000e+01        0.000000e+00
# 50%    3.600000e+01     1.000000e+00  2.800000e+01        0.000000e+00
# 75%    4.900000e+01     1.000000e+00  3.500000e+01        1.000000e+00
# max    8.500000e+01     1.000000e+00  5.200000e+01        1.000000e+00
#
#        Annual_Premium  Policy_Sales_Channel       Vintage      Response
# count    4.601919e+06          4.601919e+06  4.601919e+06  4.601919e+06
# mean     3.046679e+04          1.124356e+02  1.638628e+02  1.228333e-01
# std      1.643833e+04          5.403221e+01  7.997061e+01  3.282458e-01
# min      2.630000e+03          1.000000e+00  1.000000e+01  0.000000e+00
# 25%      2.528400e+04          2.900000e+01  9.900000e+01  0.000000e+00
# 50%      3.182900e+04          1.510000e+02  1.660000e+02  0.000000e+00
# 75%      3.944800e+04          1.520000e+02  2.320000e+02  0.000000e+00
# max      5.401650e+05          1.630000e+02  2.990000e+02  1.000000e+00
#
# Missing Values in the Train Sample:
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64
#
# Missing Values in the Test Sample:
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# dtype: int64
